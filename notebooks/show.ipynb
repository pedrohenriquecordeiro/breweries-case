# %% [markdown]
# ## Results Notebook

# %% [markdown]
# This notebook demonstrates the results of the data pipeline by loading and displaying data from Silver and Gold tables.

# %% [markdown]
# Installs the required libraries for working with Delta Lake and Google Cloud Storage.

# %%
! pip install deltalake google-cloud-storage pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 25.7 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# Sets up the environment and imports required libraries for working with Delta Lake and Google Cloud Storage.

# %%
from deltalake import DeltaTable
import pandas as pd
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/src/tests/gke-service-account.json"

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Silver

# %%
delta_table_path = 'gs://bees-storage/silver/'
dt = DeltaTable(delta_table_path)
df = dt.to_pandas()

# %%
df.head(10)
# Out:
#                    address_1 address_2 address_3 brewery_type  \
# 0  946 N Shepherd Dr Suite A      None      None        micro
# 1           Schleppe-Platz 1      None      None        large
# 2            Brauhausgasse 6      None      None        large
# 3                      L67 7      None      None         nano
# 4  Mautner-Markhof-Stra�e 11      None      None        large
#
#                        city         country  \
# 0                   Houston   United States
# 1  Klagenfurt am W�rthersee         Austria
# 2                   Villach         Austria
# 3                    Wimitz         Austria
# 4                 Schwechat         Austria
#
#                                      id   latitude  longitude  \
# 0  377038fb-785b-4d4c-bc17-2c8514340e76        NaN        NaN
# 1  c88759b6-88d6-4172-bed7-61dec61e50aa  46.641697  14.286632
# 2  f51b3f3d-be14-40da-914a-3b5c83f75bbf  46.616625  13.851682
# 3  3fe1de22-c30c-446d-b2f2-913ca9f6378e  46.839926  14.355971
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8375 entries, 0 to 8374
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   address_1       7618 non-null   object
#  1   address_2       110 non-null    object
#  2   address_3       35 non-null     object
#  3   brewery_type    8375 non-null   object
#  4   city            8375 non-null   object
#  5   country         8375 non-null   object
#  6   id              8375 non-null   object
#  7   latitude        6054 non-null   float64
#  8   longitude       6054 non-null   float64
#  9   name            8375 non-null   object
#  10  phone           7528 non-null   object
#  11  postal_code     8375 non-null   object
#  12  state           8375 non-null   object
#  13  state_province  8375 non-null   object
#  14  street          7618 non-null   object
#  15  website_url     7185 non-null   object
#  16  ingestion_at    8375 non-null   datetime64[us, UTC]
# ...

# %% [markdown]
# ## Gold

# %%
delta_table_path = 'gs://bees-storage/gold/'
dt = DeltaTable(delta_table_path)
df = dt.to_pandas()

# %%
df.head(100)
# Out:
#    brewery_type        country           state          city  brewery_count  \
# 0       brewpub  United States       Tennessee     Knoxville              8
# 1      planning  United States        Kentucky    Louisville              1
# 2       brewpub  United States           Idaho         Boise              5
# 3       brewpub  United States      California    Sacramento              5
# 4       brewpub  United States  South Carolina    Charleston              3
# ..          ...            ...             ...           ...            ...
# 95      brewpub  United States      California         Vista              3
# 96      brewpub  United States      Washington        Tacoma              3
# 97     planning  United States      California       Oakland              2
# 98     planning  United States    Pennsylvania  Philadelphia              3
# 99     contract  United States       Tennessee     Nashville              1
#
#                        ingestion_at
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5150 entries, 0 to 5149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brewery_type   5150 non-null   object
#  1   country        5150 non-null   object
#  2   state          5150 non-null   object
#  3   city           5150 non-null   object
#  4   brewery_count  5150 non-null   int64
#  5   ingestion_at   5150 non-null   datetime64[us, UTC]
# dtypes: datetime64[us, UTC](1), int64(1), object(4)
# memory usage: 241.5+ KB
